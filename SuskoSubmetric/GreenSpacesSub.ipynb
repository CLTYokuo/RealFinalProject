# %%
import pandas as pd

df =  pd.read_csv("GreenSpaces.csv")
df
# Out:
#     _id Responsibility_Parks or Operations                        Facility  \
# 0     1                         Operations               Bates St Triangle
# 1     2                         Operations            Baum Negley Triangle
# 2     3                         Operations                   Bedford Strip
# 3     4                         Operations              Beechview Monument
# 4     5                         Operations              Brookline Monument
# 5     6                         Operations                  Craft Triangle
# 6     7                         Operations                       Crosstown
# 7     8                         Operations              East Liberty Strip
# 8     9                         Operations                 Edgerton Circle
# 9    10                         Operations        Fort Duquesne Blvd Strip
# 10   11                         Operations         Frankstown Triangle 1&2
# ...

# %%
dictf =  pd.read_csv("dictionary.csv")
dictf
# Out:
#     _id                           Column Name  \
# 0     1    Responsibility_Parks or Operations
# 1     2                              Facility
# 2     3                              Division
# 3     4                         Total Acreage
# 4     5                  Maintainable Acreage
# 5     6                               Shelter
# 6     7                            Rec Center
# 7     8                         Senior Center
# 8     9                                  Pool
# 9    10                            Spray Pool
# 10   11                             Play Area
# 11   12              Tennis Court with Lights
# 12   13        Tennis Court without NO Lights
# 13   14     Basketball Full Court with Lights
# 14   15  Basketball Full Court without Lights
# 15   16     Basketball half Court with Lights
# 16   17  Basketball Half Court without Lights
# 17   18                  Basketball Standards
# 18   19                   Multi-Purpose Court
# ...

# %% [markdown]
# Neighborhoods of Parks
# 1. Central Oakland
# 2. Friendship
# 3. Bedford Dwelling
# 4. Beechview
# 5. Brookline
# 6. West Oakland
# 7. Central Business District
# 8. East Liberty
# 9. Point Breeze
# 10. Central Business District
# 11. Homewood South
# 12. Point Breeze
# 13. Central Business District
# 14. Crafton Heights
# 15. Highland Park
# 16. South Oakland
# 17. Point Breeze North
# 18. Central Business District
# 19. Point Breeze North
# 20. Shadyside
# 21. Squirrel Hill North
# 22. East Liberty
# 23. East Liberty
# 24. Central Oakland
# 25. South Oakland
# 26. Polish Hill
# 27. Regent Square
# 28. Point Breeze
# 29. Sheraden
# 30. Swisshelm Park
# 31. Homewood West
# 32. Shadyside
# 33. Swisshelm Park
# 34. Central Oakland

# %% [markdown]
# # Total Acres:
# Central Oakland - 1.3
# Friendship - 0.2
# Bedford Dwelling - 0.3
# Beechview - 0.1
# Brookline - 0.1
# West Oakland - 0.1
# Central Business District - 1.2
# East Liberty - 2.1
# Point Breeze - 0.31
# Homewood South - 1.8
# Crafton Heights - 0.1
# Highland Park - 0.05
# South Oakland - 0.14
# Point Breeze North - 0.8
# Shadyside - 0.8
# Squirrel Hill North - 0.3
# South Oakland - 0.1
# Polish Hill - 0.01
# Sheraden - 0.1
# Swisshelm Park - 0.05
# Homewood West - 0.7

# %% [markdown]
# From this submetric the best green neighborhood would be East Liberty. Unfortunately this data does not include all of the large parks such as Schenly and Highland, and many other small green spaces throughout the area of Pittsburgh. Meaning that even though the data says East Liberty is most green neighborhood and many neighborhoods do not have any green at all is technically not true. These parks are just the ones collected by the Operations Division of the Department of Public Works.
